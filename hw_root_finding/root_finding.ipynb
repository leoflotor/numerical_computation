# %%
import numpy as np
import sympy as sym
import pandas as pd

# %%
x = sym.Symbol('x')
f = 1 - x * sym.exp(1 - x)
f_prime = sym.diff(f)

f = sym.lambdify(x, f)
f_prime = sym.lambdify(x, f_prime)

# %%
def secant_root(x1, x0, iterations):
    root_list = np.array([])
    for k in range(0, iterations+1):
        x2 = x1 - f(x1) * (x1 - x0) / (f(x1) - f(x0))
        root_list = np.append(root_list, [k, x1])
        
        x0 = x1
        x1 = x2
    return root_list

# %%
def newton_root(x0, iterations):
    # n, xn, f, f', x0 - xn
    root_list = np.array([])
    for k in range(0, iterations+1):
        x1 = x0 - f(x0) / f_prime(x0)
        root_list = np.append(root_list, [k, x0])
        
        x0 = x1
        k += 1
    return root_list

# %%
secant_data = secant_root(0, -1, 20)
secant_data = np.split(secant_data, 21)
secant_data = np.array(secant_data)

# %%
newton_data = newton_root(0, 20)
newton_data = np.split(newton_data, 21)
newton_data = np.array(newton_data)

# %%
root_df = pd.DataFrame(newton_data, columns = ['n', 'newt: xn'])
root_df.set_index('n', inplace=True)

# %%
newt_diff = 1 - newton_data[:,1:]
root_df['newt: alpha - xn'] = newt_diff

# %%
sec = secant_data[:,1:]
sec_diff = 1 - sec

# %%
root_df['sec: xn'], root_df['sec: alpha - xn'] = sec, sec_diff

# %%
root_df
# Out:
#       newt: xn  newt: alpha - xn   sec: xn  sec: alpha - xn
# n
# 0.0   0.000000          1.000000  0.000000         1.000000
# 1.0   0.367879          0.632121  0.135335         0.864665
# 2.0   0.626666          0.373334  0.421193         0.578807
# 3.0   0.792119          0.207881  0.586457         0.413543
# 4.0   0.889216          0.110784  0.724548         0.275452
# 5.0   0.942618          0.057382  0.817997         0.182003
# 6.0   0.970768          0.029232  0.882865         0.117135
# 7.0   0.985243          0.014757  0.925477         0.074523
# 8.0   0.992585          0.007415  0.953106         0.046894
# 9.0   0.996283          0.003717  0.970674         0.029326
# 10.0  0.998139          0.001861  0.981742         0.018258
# 11.0  0.999069          0.000931  0.988664         0.011336
# 12.0  0.999534          0.000466  0.992974         0.007026
# 13.0  0.999767          0.000233  0.995650         0.004350
# 14.0  0.999884          0.000116  0.997308         0.002692
# 15.0  0.999942          0.000058  0.998335         0.001665
# 16.0  0.999971          0.000029  0.998971         0.001029
# 17.0  0.999985          0.000015  0.999364         0.000636
# 18.0  0.999993          0.000007  0.999607         0.000393
# 19.0  0.999996          0.000004  0.999757         0.000243
# 20.0  0.999998          0.000002  0.999850         0.000150
